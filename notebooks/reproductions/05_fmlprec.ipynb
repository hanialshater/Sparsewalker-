# %% [markdown]
# # FMLP-Rec reproduction entry point
# Frequency-domain sequential baseline recovered from the previous all-algorithms benchmark.

# %%
# !pip -q install "git+https://github.com/hanialshater/Sparsewalker-.git@main"
from sparsewalker.models import FMLPRec
m=FMLPRec(12101,50)
print(sum(p.numel() for p in m.parameters()))
