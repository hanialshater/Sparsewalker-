# %% [markdown]
# # SASRec reproduction entry point
# Canonical Beauty geometry: 12,101 items, max_len=50, d=64, 2 blocks, 2 heads. Expected trainable parameters: **877,824**.

# %%
# !pip -q install "git+https://github.com/hanialshater/Sparsewalker-.git@main"
from sparsewalker.models import SASRec
m=SASRec(12101,50)
n=sum(p.numel() for p in m.parameters())
print(n)
assert n==877824
