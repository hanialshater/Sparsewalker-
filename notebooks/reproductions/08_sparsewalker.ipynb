# %% [markdown]
# # Sparse Walker reproduction entry point
# Dynamic-support recurrent model: 65,536 concepts, K=8 active concepts, degree-4 graph, two recurrent hops in the current Beauty configuration.

# %%
# !pip -q install "git+https://github.com/hanialshater/Sparsewalker-.git@refactor-v1"
from sparsewalker.models import SparseWalker
m=SparseWalker(12101,50)
print(sum(p.numel() for p in m.parameters()))
