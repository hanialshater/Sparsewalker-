# %% [markdown]
# # GRU4Rec reproduction entry point
# Shared ID-only recurrent baseline.

# %%
# !pip -q install "git+https://github.com/hanialshater/Sparsewalker-.git@main"
from sparsewalker.models import GRU4Rec
m=GRU4Rec(12101,50)
print(sum(p.numel() for p in m.parameters()))
