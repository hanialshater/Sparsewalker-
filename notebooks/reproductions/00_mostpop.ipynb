# %% [markdown]
# # MostPop baseline
# Simple non-learned popularity baseline used as a protocol sanity check.

# %%
# !pip -q install "git+https://github.com/hanialshater/Sparsewalker-.git@main"
from sparsewalker.models import MostPop
m=MostPop(5,{1:10,2:5,3:1})
print(m.scores)
