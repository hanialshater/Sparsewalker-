# %% [markdown]
# # Mamba4Rec reproduction
# The legacy `mamba_ssm` wrapper is preserved as reference only. The next baseline task is a **portable no-custom-compile** quality path plus fast recurrent inference.

# %%
# !pip -q install "git+https://github.com/hanialshater/Sparsewalker-.git@refactor-v1"
from sparsewalker.models.mamba4rec import HAS_MAMBA
print('mamba_ssm installed:',HAS_MAMBA)
