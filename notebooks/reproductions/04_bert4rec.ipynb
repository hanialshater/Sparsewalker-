# %% [markdown]
# # BERT4Rec reproduction entry point
# Masked-item baseline. Quality is not yet canonical-stamped in this project.

# %%
# !pip -q install "git+https://github.com/hanialshater/Sparsewalker-.git@main"
from sparsewalker.models import BERT4Rec
m=BERT4Rec(12101,50)
print(sum(p.numel() for p in m.parameters()))
