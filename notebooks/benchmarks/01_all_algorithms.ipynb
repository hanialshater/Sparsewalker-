# %% [markdown]
# # All-algorithms quality benchmark
# Implementations are imported from `src/`; this notebook is orchestration only. HSTU remains on its faithful timestamp-aware reproduction protocol until shared-harness integration parity is stamped.

# %%
# !git clone -q https://github.com/hanialshater/Sparsewalker-.git /content/Sparsewalker || true
# %cd /content/Sparsewalker
# !pip -q install -e .
import sys
sys.path.insert(0,'benchmarks')
from model_registry import build_model
for name in ['SASRec','SASRec+SS','eSASRec','GRU4Rec','FMLP-Rec','BERT4Rec','SparseWalker','SparseWalker-E2E']:
    m=build_model(name,12101,50)
    print(name, sum(p.numel() for p in m.parameters()))
# Example quality run:
# !python benchmarks/run_quality.py --dataset beauty --model SASRec --epochs 12 --seed 42
